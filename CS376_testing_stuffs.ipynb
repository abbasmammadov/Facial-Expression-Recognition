# %% [markdown]
# <a href="https://colab.research.google.com/github/abbasmammadov/Facial-Expression-Recognition/blob/main/CS376_testing_stuffs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install necessary modules
# !pip install timm let's use the pytorch's inbuilt models
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.7/dist-packages (0.5.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)

# %%
#mount your drive first - you can do it once
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing necessary modules
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import torchvision.datasets as dset
import torchvision.transforms as T

# %%
#let's get the csv files from the zip file
data_path = "/content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013"
csv_path = os.path.join(data_path, 'fer2013.csv')
# from zipfile import ZipFile
# with ZipFile(data_path) as myzip:
#   data =  myzip.open('fer2013.csv') #this is used for testing the data, it doesn't contain the labels
data_df = pd.read_csv(csv_path)

# %%
#shuffle indices into training set and test sets and separate the validation data from the training data
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(data_df['pixels'], data_df['emotion'], test_size=0.2, shuffle=True)
X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=0.5, shuffle=False)

# %%
#convert each of the training and the validation datasets into dataframes
new_train = pd.DataFrame(data=X_train)
new_train['emotion'] = y_train
new_val = pd.DataFrame(data=X_val)
new_val['emotion'] = y_val
new_test = pd.DataFrame(data=X_test)
new_test['emotion'] = y_test

# %%
#now make directories to store each of the images of each categories from the pixels
os.mkdir(os.path.join(data_path, 'train'))
os.mkdir(os.path.join(data_path, 'validation'))
os.mkdir(os.path.join(data_path, 'test'))

# %%
#WARNING - EXECUTE THIS CELL ONLY ONCE, create a directory of each of the emotions
em_dict = {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'sad', 5: 'surprise', 6: 'neutral'}
os.chdir(data_path)
train_path = os.path.join(data_path, 'train')
validation_path = os.path.join(data_path, 'validation')
test_path = os.path.join(data_path, 'test')
for key in em_dict.keys():
  os.chdir(train_path)
  os.mkdir(em_dict[key])
  os.chdir(validation_path)
  os.mkdir(em_dict[key])
  os.chdir(test_path)
  os.mkdir(em_dict[key])

# %%
#save the images into each of the folders of their respective emotions
##saving each images on the training set
counter_each = {'angry': 0, 'sad': 0, 'happy': 0, 'neutral': 0, 'disgust': 0, 'fear': 0, 'surprise': 0}
for (ind, row) in new_train.iterrows():
  emotion = em_dict[row['emotion']]
  emotion_path = os.path.join(train_path, emotion)
  img = np.fromstring(row['pixels'], dtype='uint8', sep=' ')
  img = img.reshape((48, 48))
  image = Image.fromarray(img)
  counter_each[emotion] += 1
  filename = f'{emotion}{counter_each[emotion]}.jpg'
  image_path = os.path.join(emotion_path, filename)
  image.save(image_path)
  print('saved: ', filename, 'in the training set on the path: ', image_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# saved:  sad4047.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4047.jpg
# saved:  fear3315.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3315.jpg
# saved:  angry3271.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3271.jpg
# saved:  neutral4110.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4110.jpg
# saved:  sad4048.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4048.jpg
# saved:  happy5954.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5954.jpg
# saved:  neutral4111.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4111.jpg
# saved:  angry3272.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3272.jpg
# saved:  sad4049.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4049.jpg
# saved:  happy5955.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5955.jpg
# saved:  happy5956.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5956.jpg
# saved:  surprise2666.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2666.jpg
# saved:  fear3316.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3316.jpg
# saved:  angry3273.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3273.jpg
# saved:  angry3274.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3274.jpg
# saved:  neutral4112.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4112.jpg
# saved:  angry3275.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3275.jpg
# saved:  neutral4113.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4113.jpg
# saved:  fear3317.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3317.jpg
# saved:  sad4050.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4050.jpg
# saved:  sad4051.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4051.jpg
# saved:  neutral4114.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4114.jpg
# saved:  happy5957.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5957.jpg
# saved:  sad4052.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4052.jpg
# saved:  happy5958.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5958.jpg
# saved:  happy5959.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5959.jpg
# saved:  neutral4115.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4115.jpg
# saved:  fear3318.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3318.jpg
# saved:  surprise2667.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2667.jpg
# saved:  sad4053.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4053.jpg
# saved:  neutral4116.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4116.jpg
# saved:  angry3276.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3276.jpg
# saved:  fear3319.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3319.jpg
# saved:  surprise2668.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2668.jpg
# saved:  happy5960.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5960.jpg
# saved:  happy5961.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5961.jpg
# saved:  happy5962.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5962.jpg
# saved:  angry3277.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3277.jpg
# saved:  happy5963.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5963.jpg
# saved:  fear3320.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3320.jpg
# saved:  angry3278.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3278.jpg
# saved:  sad4054.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4054.jpg
# saved:  neutral4117.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4117.jpg
# saved:  happy5964.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5964.jpg
# saved:  sad4055.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4055.jpg
# saved:  sad4056.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4056.jpg
# saved:  fear3321.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3321.jpg
# saved:  happy5965.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5965.jpg
# saved:  surprise2669.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2669.jpg
# saved:  sad4057.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4057.jpg
# saved:  happy5966.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5966.jpg
# saved:  fear3322.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3322.jpg
# saved:  neutral4118.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4118.jpg
# saved:  sad4058.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4058.jpg
# saved:  sad4059.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4059.jpg
# saved:  fear3323.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3323.jpg
# saved:  surprise2670.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2670.jpg
# saved:  fear3324.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3324.jpg
# saved:  disgust353.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/disgust/disgust353.jpg
# saved:  neutral4119.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4119.jpg
# saved:  neutral4120.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4120.jpg
# saved:  happy5967.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5967.jpg
# saved:  happy5968.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5968.jpg
# saved:  neutral4121.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4121.jpg
# saved:  surprise2671.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2671.jpg
# saved:  sad4060.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4060.jpg
# saved:  sad4061.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4061.jpg
# saved:  surprise2672.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2672.jpg
# saved:  fear3325.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3325.jpg
# saved:  happy5969.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5969.jpg
# saved:  neutral4122.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4122.jpg
# saved:  fear3326.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3326.jpg
# saved:  sad4062.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4062.jpg
# saved:  sad4063.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4063.jpg
# saved:  disgust354.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/disgust/disgust354.jpg
# saved:  happy5970.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5970.jpg
# saved:  neutral4123.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4123.jpg
# saved:  happy5971.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5971.jpg
# saved:  sad4064.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4064.jpg
# saved:  sad4065.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4065.jpg
# saved:  happy5972.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5972.jpg
# saved:  fear3327.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3327.jpg
# saved:  surprise2673.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2673.jpg
# saved:  neutral4124.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4124.jpg
# saved:  surprise2674.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2674.jpg
# saved:  fear3328.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3328.jpg
# saved:  fear3329.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3329.jpg
# saved:  angry3279.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3279.jpg
# saved:  angry3280.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3280.jpg
# saved:  neutral4125.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4125.jpg
# saved:  angry3281.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3281.jpg
# saved:  angry3282.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3282.jpg
# saved:  sad4066.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4066.jpg
# saved:  angry3283.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3283.jpg
# saved:  disgust355.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/disgust/disgust355.jpg
# saved:  neutral4126.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4126.jpg
# saved:  surprise2675.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2675.jpg
# saved:  fear3330.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3330.jpg
# saved:  angry3284.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3284.jpg
# saved:  sad4067.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4067.jpg
# saved:  angry3285.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3285.jpg
# saved:  fear3331.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3331.jpg
# saved:  fear3332.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3332.jpg
# saved:  surprise2676.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2676.jpg
# saved:  fear3333.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3333.jpg
# saved:  angry3286.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3286.jpg
# saved:  neutral4127.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4127.jpg
# saved:  angry3287.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3287.jpg
# saved:  neutral4128.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4128.jpg
# saved:  surprise2677.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2677.jpg
# saved:  angry3288.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3288.jpg
# saved:  surprise2678.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2678.jpg
# saved:  sad4068.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4068.jpg
# saved:  angry3289.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3289.jpg
# saved:  sad4069.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4069.jpg
# saved:  happy5973.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5973.jpg
# saved:  neutral4129.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4129.jpg
# saved:  angry3290.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3290.jpg
# saved:  surprise2679.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2679.jpg
# saved:  neutral4130.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4130.jpg
# saved:  neutral4131.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4131.jpg
# saved:  angry3291.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3291.jpg
# saved:  angry3292.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3292.jpg
# saved:  sad4070.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4070.jpg
# saved:  surprise2680.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2680.jpg
# saved:  happy5974.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5974.jpg
# saved:  surprise2681.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2681.jpg
# saved:  angry3293.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3293.jpg
# saved:  fear3334.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3334.jpg
# saved:  surprise2682.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2682.jpg
# saved:  happy5975.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5975.jpg
# saved:  happy5976.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5976.jpg
# saved:  happy5977.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5977.jpg
# saved:  neutral4132.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4132.jpg
# saved:  surprise2683.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2683.jpg
# saved:  surprise2684.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2684.jpg
# saved:  sad4071.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4071.jpg
# saved:  neutral4133.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4133.jpg
# saved:  angry3294.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3294.jpg
# saved:  fear3335.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3335.jpg
# saved:  fear3336.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3336.jpg
# saved:  happy5978.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5978.jpg
# saved:  neutral4134.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4134.jpg
# saved:  fear3337.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3337.jpg
# saved:  fear3338.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3338.jpg
# saved:  fear3339.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3339.jpg
# saved:  happy5979.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5979.jpg
# saved:  neutral4135.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4135.jpg
# saved:  neutral4136.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4136.jpg
# saved:  neutral4137.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4137.jpg
# saved:  angry3295.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3295.jpg
# saved:  neutral4138.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4138.jpg
# saved:  angry3296.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3296.jpg
# saved:  happy5980.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5980.jpg
# saved:  fear3340.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3340.jpg
# saved:  sad4072.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4072.jpg
# saved:  angry3297.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3297.jpg
# saved:  happy5981.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5981.jpg
# saved:  fear3341.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3341.jpg
# saved:  sad4073.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4073.jpg
# saved:  neutral4139.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4139.jpg
# saved:  happy5982.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5982.jpg
# saved:  disgust356.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/disgust/disgust356.jpg
# saved:  fear3342.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3342.jpg
# saved:  surprise2685.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2685.jpg
# saved:  fear3343.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3343.jpg
# saved:  angry3298.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3298.jpg
# saved:  sad4074.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4074.jpg
# saved:  sad4075.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4075.jpg
# saved:  angry3299.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3299.jpg
# saved:  surprise2686.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2686.jpg
# saved:  surprise2687.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2687.jpg
# saved:  surprise2688.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2688.jpg
# saved:  happy5983.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5983.jpg
# saved:  happy5984.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5984.jpg
# saved:  sad4076.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4076.jpg
# saved:  surprise2689.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2689.jpg
# saved:  angry3300.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3300.jpg
# saved:  surprise2690.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2690.jpg
# saved:  happy5985.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5985.jpg
# saved:  angry3301.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3301.jpg
# saved:  sad4077.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4077.jpg
# saved:  neutral4140.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4140.jpg
# saved:  fear3344.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3344.jpg
# saved:  surprise2691.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2691.jpg
# saved:  fear3345.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3345.jpg
# saved:  happy5986.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5986.jpg
# saved:  happy5987.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5987.jpg
# saved:  surprise2692.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2692.jpg
# saved:  fear3346.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3346.jpg
# saved:  angry3302.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3302.jpg
# saved:  surprise2693.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2693.jpg
# saved:  fear3347.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3347.jpg
# saved:  happy5988.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5988.jpg
# saved:  neutral4141.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4141.jpg
# saved:  neutral4142.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4142.jpg
# saved:  happy5989.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5989.jpg
# saved:  sad4078.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4078.jpg
# saved:  neutral4143.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4143.jpg
# saved:  surprise2694.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2694.jpg
# saved:  angry3303.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3303.jpg
# saved:  fear3348.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3348.jpg
# saved:  happy5990.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5990.jpg
# saved:  happy5991.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5991.jpg
# saved:  happy5992.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5992.jpg
# saved:  disgust357.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/disgust/disgust357.jpg
# saved:  fear3349.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3349.jpg
# saved:  happy5993.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5993.jpg
# saved:  sad4079.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4079.jpg
# saved:  happy5994.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5994.jpg
# saved:  sad4080.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4080.jpg
# saved:  angry3304.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3304.jpg
# saved:  sad4081.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4081.jpg
# saved:  happy5995.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5995.jpg
# saved:  happy5996.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5996.jpg
# saved:  angry3305.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3305.jpg
# saved:  neutral4144.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4144.jpg
# saved:  neutral4145.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4145.jpg
# saved:  angry3306.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3306.jpg
# saved:  sad4082.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4082.jpg
# saved:  fear3350.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3350.jpg
# saved:  happy5997.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5997.jpg
# saved:  surprise2695.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2695.jpg
# saved:  neutral4146.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4146.jpg
# saved:  neutral4147.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4147.jpg
# saved:  fear3351.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3351.jpg
# saved:  sad4083.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4083.jpg
# saved:  neutral4148.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4148.jpg
# saved:  surprise2696.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise2696.jpg
# saved:  fear3352.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3352.jpg
# saved:  sad4084.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4084.jpg
# saved:  fear3353.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear3353.jpg
# saved:  sad4085.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4085.jpg
# saved:  sad4086.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4086.jpg
# saved:  angry3307.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3307.jpg
# saved:  neutral4149.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4149.jpg
# saved:  happy5998.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5998.jpg
# saved:  neutral4150.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4150.jpg
# saved:  neutral4151.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4151.jpg
# saved:  neutral4152.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4152.jpg
# saved:  happy5999.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy5999.jpg
# ...
# saved:  neutral4954.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4954.jpg
# saved:  happy7151.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7151.jpg
# saved:  happy7152.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7152.jpg
# saved:  happy7153.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7153.jpg
# saved:  happy7154.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7154.jpg
# saved:  sad4896.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4896.jpg
# saved:  neutral4955.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4955.jpg
# saved:  happy7155.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7155.jpg
# saved:  disgust445.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/disgust/disgust445.jpg
# saved:  happy7156.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7156.jpg
# saved:  angry3947.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3947.jpg
# saved:  angry3948.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3948.jpg
# saved:  sad4897.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4897.jpg
# saved:  neutral4956.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4956.jpg
# saved:  sad4898.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4898.jpg
# saved:  angry3949.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3949.jpg
# saved:  surprise3202.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3202.jpg
# saved:  angry3950.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3950.jpg
# saved:  happy7157.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7157.jpg
# saved:  sad4899.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4899.jpg
# saved:  surprise3203.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3203.jpg
# saved:  surprise3204.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3204.jpg
# saved:  neutral4957.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4957.jpg
# saved:  angry3951.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3951.jpg
# saved:  happy7158.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7158.jpg
# saved:  surprise3205.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3205.jpg
# saved:  neutral4958.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4958.jpg
# saved:  angry3952.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3952.jpg
# saved:  angry3953.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3953.jpg
# saved:  angry3954.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3954.jpg
# saved:  sad4900.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4900.jpg
# saved:  angry3955.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3955.jpg
# saved:  fear4041.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4041.jpg
# saved:  neutral4959.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4959.jpg
# saved:  fear4042.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4042.jpg
# saved:  neutral4960.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4960.jpg
# saved:  fear4043.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4043.jpg
# saved:  happy7159.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7159.jpg
# saved:  surprise3206.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3206.jpg
# saved:  neutral4961.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4961.jpg
# saved:  happy7160.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7160.jpg
# saved:  sad4901.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4901.jpg
# saved:  happy7161.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7161.jpg
# saved:  neutral4962.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4962.jpg
# saved:  happy7162.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7162.jpg
# saved:  happy7163.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7163.jpg
# saved:  angry3956.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3956.jpg
# saved:  happy7164.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7164.jpg
# saved:  happy7165.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7165.jpg
# saved:  happy7166.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7166.jpg
# saved:  surprise3207.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3207.jpg
# saved:  fear4044.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4044.jpg
# saved:  angry3957.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3957.jpg
# saved:  angry3958.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3958.jpg
# saved:  neutral4963.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4963.jpg
# saved:  happy7167.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7167.jpg
# saved:  happy7168.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7168.jpg
# saved:  surprise3208.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3208.jpg
# saved:  angry3959.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3959.jpg
# saved:  happy7169.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7169.jpg
# saved:  neutral4964.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4964.jpg
# saved:  happy7170.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7170.jpg
# saved:  surprise3209.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3209.jpg
# saved:  fear4045.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4045.jpg
# saved:  fear4046.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4046.jpg
# saved:  happy7171.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7171.jpg
# saved:  fear4047.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4047.jpg
# saved:  sad4902.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/sad/sad4902.jpg
# saved:  fear4048.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4048.jpg
# saved:  fear4049.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4049.jpg
# saved:  happy7172.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7172.jpg
# saved:  angry3960.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3960.jpg
# saved:  angry3961.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3961.jpg
# saved:  angry3962.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3962.jpg
# saved:  happy7173.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7173.jpg
# saved:  angry3963.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/angry/angry3963.jpg
# saved:  happy7174.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/happy/happy7174.jpg
# saved:  neutral4965.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/neutral/neutral4965.jpg
# saved:  fear4050.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/fear/fear4050.jpg
# saved:  surprise3210.jpg in the training set on the path:  /content/drive/.shortcut-targets-by-id/1obcqAzYI6A4bH7eOspkm6IYdYeH9LMHS/ML Project Folder/project/datasets/fer2013/train/surprise/surprise3210.jpg

# %%
##saving each images on the validation set
counter_each = {'angry': 0, 'sad': 0, 'happy': 0, 'neutral': 0, 'disgust': 0, 'fear': 0, 'surprise': 0}
for (ind, row) in new_val.iterrows():
  emotion = em_dict[row['emotion']]
  emotion_path = os.path.join(validation_path, emotion)
  img = np.fromstring(row['pixels'], dtype='uint8', sep=' ')
  img = img.reshape((48, 48))
  image = Image.fromarray(img)
  counter_each[emotion] += 1
  filename = f'{emotion}{counter_each[emotion]}.jpg'
  image_path = os.path.join(emotion_path, filename)  
  image.save(image_path)
  #print('saved: ', filename, 'in the validation set on the path: ', image_path)

# %%
##saving each images on the test set
counter_each = {'angry': 0, 'sad': 0, 'happy': 0, 'neutral': 0, 'disgust': 0, 'fear': 0, 'surprise': 0}
for (ind, row) in new_val.iterrows():
  emotion = em_dict[row['emotion']]
  emotion_path = os.path.join(test_path, emotion)
  img = np.fromstring(row['pixels'], dtype='uint8', sep=' ')
  img = img.reshape((48, 48))
  image = Image.fromarray(img)
  counter_each[emotion] += 1
  filename = f'{emotion}{counter_each[emotion]}.jpg'
  image_path = os.path.join(emotion_path, filename)  
  image.save(image_path)
 # print('saved: ', filename, 'in the test set on the path: ', image_path)

# %%
#hyperparameters
lr = 1e-3
batch_size = 32
epochs = 3

#device
device = 'cpu'
if torch.cuda.is_available():
  device = 'cuda'
  print('GPU available')
else:
  print('training is done on CPU')
# Out:
# GPU available

# %%
#now let's load the dataset into the 'dataloader' package of pytorch
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

# %%
#first step is creating an augmentation cell using transforms of pytorch
train_augs = T.Compose([T.RandomHorizontalFlip(p=0.5), 
                        T.RandomRotation(degrees=(-10, +10)),
                        T.RandomAffine(degrees=(-10, +10), translate=(0.1, 0.2)),
                        #add zoom later 
                        T.ToTensor()])

valid_augs = T.Compose([T.ToTensor()])

test_augs = T.Compose([T.ToTensor()])

# %%
trainset = ImageFolder(train_path, transform=train_augs)
validset = ImageFolder(validation_path, transform=valid_augs)
testset = ImageFolder(test_path, transform=test_augs)
print(f"Total no. of examples in trainset : {len(trainset)}")
print(f"Total no. of examples in validset : {len(validset)}")
print(f"Total no. of examples in testset : {len(testset)}")
# Out:
# Total no. of examples in trainset : 28709
# Total no. of examples in validset : 3589
# Total no. of examples in testset : 3589

# %%
print(trainset.class_to_idx)
# Out:
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
#we can view some images and their labels
import matplotlib.pyplot as plt
idx = np.random.randint(low=0, high=len(trainset)-1)
print('chosen index: ', idx)
image, label = trainset[idx] # the image has format of h, w, c -> so it have to be reshaped
plt.imshow(image.permute(1, 2, 0))
plt.title(label)
# Out:
# chosen index:  6422
# Text(0.5, 1.0, '2')

# %%
#now let's read the dataset using pytorch's dataloader
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
validloader = DataLoader(validset, batch_size=batch_size)
testloader = DataLoader(testset, batch_size=batch_size)
print('total batches in trainloader: ', len(trainloader), ', validloader: ', len(validloader), ', and testloader', len(testloader))
# Out:
# total batches in trainloader:  898 , validloader:  113 , and testloader 113

# %%
#checking the shapes of each batch
for images, labels in trainloader:
  break
print(f'shape of a batch of images: {images.shape}')
print(f'shape of a batch of labels: {labels.shape}')
# Out:
# shape of a batch of images: torch.Size([32, 3, 48, 48])
# shape of a batch of labels: torch.Size([32])

# %%
# #create a model
# import timm
# from torch import nn as nn
# from torchvision import models
# class FacialClassification(nn.Module):

#   def __init__(self):
#     super(FacialClassification, self).__init__()

#     self.resnet50 = timm.create_model('resnet50', pretrained=False, num_classes=7)
  
#   def forward(self, images, labels=None):
#     scores = self.resnet50(images)
#     if labels!=None:
#       loss = nn.CrossEntropyLoss()(scores, labels)
#       return scores, loss
#     return scores
#we can use pytorch's inbuilt models

# %%
# model = FacialClassification()
model = models.resnet50(pretrained=False)
model.to(device)
# Out:
# FacialClassification(
#   (resnet50): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act3): ReLU(inplace=True)
#       )
#     )
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=2048, out_features=7, bias=True)
#   )
# )

# %%
#accuracy of the model
from tqdm import tqdm
def multiclass_accuracy(y_pred,y_true):
    top_p,top_class = y_pred.topk(1,dim = 1)
    equals = top_class == y_true.view(*top_class.shape)
    return torch.mean(equals.type(torch.FloatTensor))

# %%
#building the train and eval functions (training the model on the training and on the validation set)
def train_model(model, dataloader, optimizer, current_epoch):

  model.train()
  total_loss = 0.0
  total_acc = 0.0
  tk = tqdm(dataloader, desc='EPOCH' + '[TRAIN]' + str(current_epoch + 1) + "/" + str(epochs))

  for t, data in enumerate(tk):
    images, labels = data
    images, labels = images.to(device), labels.to(device)

    optimizer.zero_grad()
    logits = model(images)
    loss = nn.CrossEntropyLoss()(logits,  labels)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()
    total_acc += multiclass_accuracy(logits, labels)
    tk.set_postfix({'loss': float(total_loss/(t+1)),'acc': float(total_acc/(t+1))})
  return total_loss/len(dataloader), total_acc / len(dataloader)

def eval_model(model, dataloader, current_epoch):

  model.eval()
  total_loss = 0.0
  total_acc = 0.0
  tk = tqdm(dataloader, desc='EPOCH' + '[VALID]' + str(current_epoch + 1) + "/" + str(epochs))

  for t, data in enumerate(tk):
    images, labels = data
    images, labels = images.to(device), labels.to(device)

    # optimizer.zero_grad()
    logits = model(images)
    loss = nn.CrossEntropyLoss()(logits,  labels)
    # loss.backward()
    # optimizer.step()
    #so the above 3 lines should be commented out, because on the validation and on the testing dataset, we won't actually try to optimize the model
    #we just have to record the accuracy. so I commented the code which optimizes the validation and the testing dataset.

    total_loss += loss.item()
    total_acc += multiclass_accuracy(logits, labels)
    tk.set_postfix({'loss': float(total_loss/(t+1)),'acc': float(total_acc/(t+1))})
  return total_loss/len(dataloader), total_acc / len(dataloader)

def test_model(model, dataloader, current_epoch):

  model.eval()
  total_loss = 0.0
  total_acc = 0.0
  tk = tqdm(dataloader, desc='EPOCH' + '[TEST]' + str(current_epoch + 1) + "/" + str(epochs))

  for t, data in enumerate(tk):
    images, labels = data
    images, labels = images.to(device), labels.to(device)

    # optimizer.zero_grad()
    logits = model(images)
    loss = nn.CrossEntropyLoss()(logits,  labels)
    # loss.backward()
    # optimizer.step()
    #same reason as the above

    total_loss += loss.item()
    total_acc += multiclass_accuracy(logits, labels)
    tk.set_postfix({'loss': float(total_loss/(t+1)),'acc': float(total_acc/(t+1))})
  return total_loss/len(dataloader), total_acc / len(dataloader)

# %%
#now let's train the model
from torch import optim
# optimizer = optim.Adam(model.parameters(), lr=lr)
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.5, weight_decay=1e-2, nesterov=True) # gives much better accuracy

# %%
best_valid_loss = np.Inf
for i in range(epochs):
  train_loss, train_acc = train_model(model, trainloader, optimizer, i)
  valid_loss, valid_acc = eval_model(model, validloader, i)
  if valid_loss < best_valid_loss:
    torch.save(model.state_dict(), 'best-weights.pt')
    print('SAVED BEST WEIGHTS')
    best_valid_loss = valid_loss
print()
print()
print('accuracy on the training set: ', float(train_acc))
print('accuracy on the validation set: ', float(valid_acc))
# Out:
# EPOCH[TRAIN]1/3: 100%|██████████| 898/898 [01:39<00:00,  9.04it/s, loss=1.8, acc=0.248]
# EPOCH[VALID]1/3: 100%|██████████| 113/113 [00:07<00:00, 15.49it/s, loss=1.77, acc=0.279]
# SAVED BEST WEIGHTS
# EPOCH[TRAIN]2/3: 100%|██████████| 898/898 [01:36<00:00,  9.35it/s, loss=1.79, acc=0.259]
# EPOCH[VALID]2/3: 100%|██████████| 113/113 [00:07<00:00, 15.57it/s, loss=1.78, acc=0.268]
# EPOCH[TRAIN]3/3: 100%|██████████| 898/898 [01:35<00:00,  9.36it/s, loss=1.78, acc=0.263]
# EPOCH[VALID]3/3: 100%|██████████| 113/113 [00:07<00:00, 15.30it/s, loss=1.76, acc=0.278]
# SAVED BEST WEIGHTS
#
#
# accuracy on the training set:  0.2626252770423889
# accuracy on the validation set:  0.27826327085494995

# %%
best_test_loss = np.Inf
for i in range(epochs):
  test_loss, test_acc = test_model(model, testloader, i) #define test_model function
  if test_loss < best_test_loss:
    torch.save(model.state_dict(), 'best-weights.pt')
    print('SAVED BEST WEIGHTS')
    best_test_loss = test_loss
print()
print()
print('accuracy on the test set: ', float(test_acc))
# Out:
# EPOCH[TEST]1/3: 100%|██████████| 113/113 [00:07<00:00, 14.30it/s, loss=1.76, acc=0.278]
# SAVED BEST WEIGHTS
# EPOCH[TEST]2/3: 100%|██████████| 113/113 [00:07<00:00, 14.98it/s, loss=1.76, acc=0.278]
# EPOCH[TEST]3/3: 100%|██████████| 113/113 [00:07<00:00, 15.02it/s, loss=1.76, acc=0.278]
# accuracy on the test set:  0.27826327085494995
